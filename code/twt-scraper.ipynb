# %%
'''The following code is deprecated following the disabling of viewing tweets publically in 2023'''
# Out:
# 'The following code is deprecated following the disabling of viewing tweets publically in 2023'

# %% [markdown]
# ### install dependencies, import modules

# %%
#install scraper
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\alist\appdata\local\temp\pip-req-build-m1hpdqbp
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\alist\AppData\Local\Temp\pip-req-build-m1hpdqbp'
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
import os
import snscrape.modules.twitter as sntwitter

# %% [markdown]
# ### implementation

# %%
'''
Call API Using Snscrape CLI commands.
sample commands:
#snscrape --jsonl --progress --max-results 500 --since 2020-06-01 twitter-search "its the elephant until:2020-07-31" > name_file.json
'''
cmd = 'snscrape --jsonl --since 2025-05-01 twitter-search "squid game until:2025-7-10" > new_squid.json'
os.system(cmd)

# %%
#check returned tweets
result = pd.read_json(r"new_squid.json", lines=True)
result.shape
# Out:
# (0, 0)

# %%
#unpack json
with open(r'new_squid.json') as f:
    lines = []
    for i in range(300000):
        for line in f:
            data = json.loads(line)
# Out:
# []

# %%
tweets = pd.DataFrame.from_dict(data)

# %%
tweets.head()

# %%
tweets.shape
# Out:
# (23, 28)

# %%
tweets.tail()
# Out:
#                                          _type  \
# rawDescription  snscrape.modules.twitter.Tweet
# statusesCount   snscrape.modules.twitter.Tweet
# url             snscrape.modules.twitter.Tweet
# username        snscrape.modules.twitter.Tweet
# verified        snscrape.modules.twitter.Tweet
#
#                                                               url  \
# rawDescription  https://twitter.com/JlaTartinedraa/status/1444...
# statusesCount   https://twitter.com/JlaTartinedraa/status/1444...
# url             https://twitter.com/JlaTartinedraa/status/1444...
# username        https://twitter.com/JlaTartinedraa/status/1444...
# verified        https://twitter.com/JlaTartinedraa/status/1444...
#
#                                      date  \
# rawDescription  2021-10-03T00:22:05+00:00
# statusesCount   2021-10-03T00:22:05+00:00
# url             2021-10-03T00:22:05+00:00
# username        2021-10-03T00:22:05+00:00
# verified        2021-10-03T00:22:05+00:00
#
# ...

# %%
#drop duplicate tweets 
tweets.drop_duplicates(subset=['id'], inplace=True)
tweets.shape
# Out:
# (66290, 28)

# %%
#select tweets with coordinates available

loc_tweets = tweets[tweets['coordinates'].isnull() == False]
loc_tweets.head()
# Out:
#                               _type  \
# 6    snscrape.modules.twitter.Tweet
# 7    snscrape.modules.twitter.Tweet
# 67   snscrape.modules.twitter.Tweet
# 119  snscrape.modules.twitter.Tweet
# 183  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 6    https://twitter.com/Rastas4J09/status/13447951...
# 7    https://twitter.com/Layito023/status/134479515...
# 67   https://twitter.com/TheRealKDeppz/status/13447...
# 119  https://twitter.com/jenzerr/status/13447800015...
# 183  https://twitter.com/Letiveg/status/13447726445...
#
#                          date  \
# 6   2020-12-31 23:58:47+00:00
# 7   2020-12-31 23:58:45+00:00
# 67  2020-12-31 23:24:55+00:00
# 119 2020-12-31 22:58:31+00:00
# 183 2020-12-31 22:29:17+00:00
#
#                                                content  \
# 6    Top 10 TV I watched in 2020 (in no particular ...
# 7    The Crown y The Queen's Gambit https://t.co/Xm...
# ...

# %%
loc_tweets['coordinates'].sample(12)
# Out:
# 167980    {'_type': 'snscrape.modules.twitter.Coordinate...
# 162365    {'_type': 'snscrape.modules.twitter.Coordinate...
# 98643     {'_type': 'snscrape.modules.twitter.Coordinate...
# 59310     {'_type': 'snscrape.modules.twitter.Coordinate...
# 253388    {'_type': 'snscrape.modules.twitter.Coordinate...
# 38029     {'_type': 'snscrape.modules.twitter.Coordinate...
# 177159    {'_type': 'snscrape.modules.twitter.Coordinate...
# 196490    {'_type': 'snscrape.modules.twitter.Coordinate...
# 95945     {'_type': 'snscrape.modules.twitter.Coordinate...
# 153304    {'_type': 'snscrape.modules.twitter.Coordinate...
# 158994    {'_type': 'snscrape.modules.twitter.Coordinate...
# 218509    {'_type': 'snscrape.modules.twitter.Coordinate...
# Name: coordinates, dtype: object

# %% [markdown]
# ### Download to csv

# %%
'''
remember to change filename!!
'''

tweets.to_csv('[FILENAME].csv', sep=',', columns=['date', 'id', 'renderedContent', 'lang', 'hashtags', 'coordinates', 'place'])
